# %% [markdown]
# ### Setup

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/MADE/Final_Project")

# %%
import cv2
import glob

from tqdm.notebook import tqdm

from google.colab.patches import cv2_imshow

# %%
train_frames_dir = "data/frames/train/"
val_frames_dir = "data/frames/validation/"

print(len(os.listdir(train_frames_dir)))
print(len(os.listdir(val_frames_dir)))
# Out:
# 84
# 21

# %% [markdown]
# ### Utils

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def get_face_bbox(image_path):
  img = cv2.imread(image_path)
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.3, 5)

  if len(faces) == 0:
    return None
  
  if len(faces) == 1:
    face = faces[0]
  
  if len(faces) > 1:
    # finding larges face by area
    face = faces[0]
    for f in faces[1:]:

      # area = w * h
      if f[2] * f[3] > face[2] * face[3]:
        face = f
  
  x, y, w, h = face
  x1, y1 = x, y
  x2, y2 = x + w, y + h

  return x1, y1, x2, y2

# %%
# image_path = glob.glob(train_frames_dir + "*/*.jpg")[0]
# image_path

# %%
# img = cv2.imread(image_path)
# bbox = get_face_bbox(image_path)
# if bbox:
#   x1, y1, x2, y2 = bbox
# else:
#   print("No face")

# %%
# img = cv2.rectangle(img, (x1, y1), (x2, y2), (255,0,0), 2)
# cv2_imshow(img)

# %%
# cropped_face = img[y1:y2, x1:x2]
# cv2_imshow(cropped_face)

# %% [markdown]
# ### Main

# %%
import json

# %%
def update_list_of_items(filepath, new_item):
  with open(filepath, "r") as f:
    list_of_items = json.loads(f.read())
  
  list_of_items.append(new_item)

  with open(filepath, "w") as f:
    f.write(json.dumps(list_of_items))

  print(f"Updated '{filepath}'.\n")

# %%
train_already_proccessed_file = "notebooks/train_already_proccessed_sub_folders"

# %%
with open(train_already_proccessed_file, "r") as f:
  train_already_proccessed_sub_folders = json.loads(f.read())

len(train_already_proccessed_sub_folders)
# Out:
# 84

# %%
# train frames

face_not_found_frames = []

for i, sub_folder in enumerate(sorted(os.listdir(train_frames_dir))):
  if sub_folder in train_already_proccessed_sub_folders:
    print(f"{ i + 1} / {len(os.listdir(train_frames_dir))}, {sub_folder} Already processed, skipping it.")
    continue

  print(f"{ i + 1} / {len(os.listdir(train_frames_dir))}, {sub_folder}")
  for frame in tqdm(sorted(os.listdir(os.path.join(train_frames_dir, sub_folder)))):
    if frame.endswith(".txt"):
      continue

    frame_path = os.path.join(train_frames_dir, sub_folder, frame)
    bbox = get_face_bbox(frame_path)

    if not bbox:
      face_not_found_frames.append(frame_path)
      continue

    bbox_filepath = frame_path.replace(".jpg", ".txt")
    with open(bbox_filepath, "w") as fin:
      fin.write(" ".join(map(str, bbox)))

  update_list_of_items(filepath=train_already_proccessed_file, new_item=sub_folder)
# Out:
# 1 / 84, subject_50_Vid_1 Already processed, skipping it.
# 2 / 84, subject_50_Vid_2 Already processed, skipping it.
# 3 / 84, subject_50_Vid_3 Already processed, skipping it.
# 4 / 84, subject_50_Vid_4 Already processed, skipping it.
# 5 / 84, subject_50_Vid_5 Already processed, skipping it.
# 6 / 84, subject_50_Vid_6 Already processed, skipping it.
# 7 / 84, subject_51_Vid_7 Already processed, skipping it.
# 8 / 84, subject_52_Vid_7 Already processed, skipping it.
# 9 / 84, subject_53_Vid_2 Already processed, skipping it.
# 10 / 84, subject_53_Vid_3 Already processed, skipping it.
# 11 / 84, subject_53_Vid_4 Already processed, skipping it.
# 12 / 84, subject_53_Vid_5 Already processed, skipping it.
# 13 / 84, subject_54_Vid_6 Already processed, skipping it.
# 14 / 84, subject_55_Vid_6 Already processed, skipping it.
# 15 / 84, subject_56_Vid_1 Already processed, skipping it.
# 16 / 84, subject_56_Vid_2 Already processed, skipping it.
# 17 / 84, subject_56_Vid_3 Already processed, skipping it.
# 18 / 84, subject_56_Vid_4 Already processed, skipping it.
# 19 / 84, subject_56_Vid_5 Already processed, skipping it.
# 20 / 84, subject_56_Vid_6 Already processed, skipping it.
# 21 / 84, subject_57_Vid_7 Already processed, skipping it.
# 22 / 84, subject_58_Vid_7 Already processed, skipping it.
# 23 / 84, subject_59_Vid_7 Already processed, skipping it.
# 24 / 84, subject_60_Vid_6-007 Already processed, skipping it.
# 25 / 84, subject_60_Vid_7 Already processed, skipping it.
# 26 / 84, subject_62_Vid_1 Already processed, skipping it.
# 27 / 84, subject_62_Vid_2 Already processed, skipping it.
# 28 / 84, subject_62_Vid_3 Already processed, skipping it.
# 29 / 84, subject_62_Vid_4 Already processed, skipping it.
# 30 / 84, subject_62_Vid_5 Already processed, skipping it.
# 31 / 84, subject_63_Vid_7 Already processed, skipping it.
# 32 / 84, subject_64_Vid_6 Already processed, skipping it.
# 33 / 84, subject_64_Vid_7 Already processed, skipping it.
# 34 / 84, subject_65_Vid_6 Already processed, skipping it.
# 35 / 84, subject_66_Vid_6 Already processed, skipping it.
# 36 / 84, subject_66_Vid_7 Already processed, skipping it.
# 37 / 84, subject_67_Vid_1 Already processed, skipping it.
# 38 / 84, subject_67_Vid_2 Already processed, skipping it.
# 39 / 84, subject_67_Vid_4 Already processed, skipping it.
# 40 / 84, subject_67_Vid_5 Already processed, skipping it.
# 41 / 84, subject_67_Vid_6-011 Already processed, skipping it.
# 42 / 84, subject_68_Vid_6 Already processed, skipping it.
# 43 / 84, subject_68_Vid_7 Already processed, skipping it.
# 44 / 84, subject_69_Vid_6 Already processed, skipping it.
# 45 / 84, subject_69_Vid_7 Already processed, skipping it.
# 46 / 84, subject_70_Vid_1 Already processed, skipping it.
# 47 / 84, subject_70_Vid_2 Already processed, skipping it.
# 48 / 84, subject_70_Vid_3 Already processed, skipping it.
# 49 / 84, subject_70_Vid_4 Already processed, skipping it.
# 50 / 84, subject_70_Vid_5 Already processed, skipping it.
# 51 / 84, subject_70_Vid_6 Already processed, skipping it.
# 52 / 84, subject_72_Vid_6 Already processed, skipping it.
# 53 / 84, subject_73_Vid_6 Already processed, skipping it.
# 54 / 84, subject_73_Vid_7 Already processed, skipping it.
# 55 / 84, subject_74_Vid_7 Already processed, skipping it.
# 56 / 84, subject_75_Vid_7 Already processed, skipping it.
# 57 / 84, subject_76_Vid_6 Already processed, skipping it.
# 58 / 84, subject_76_Vid_7 Already processed, skipping it.
# 59 / 84, subject_77_Vid_1 Already processed, skipping it.
# 60 / 84, subject_77_Vid_2 Already processed, skipping it.
# 61 / 84, subject_77_Vid_3 Already processed, skipping it.
# 62 / 84, subject_77_Vid_4 Already processed, skipping it.
# 63 / 84, subject_77_Vid_5 Already processed, skipping it.
# 64 / 84, subject_77_Vid_7 Already processed, skipping it.
# 65 / 84, subject_78_Vid_6 Already processed, skipping it.
# 66 / 84, subject_79_Vid_7 Already processed, skipping it.
# 67 / 84, subject_80_Vid_1 Already processed, skipping it.
# 68 / 84, subject_80_Vid_2 Already processed, skipping it.
# 69 / 84, subject_80_Vid_3 Already processed, skipping it.
# 70 / 84, subject_80_Vid_4 Already processed, skipping it.
# 71 / 84, subject_80_Vid_5 Already processed, skipping it.
# 72 / 84, subject_80_Vid_6 Already processed, skipping it.
# 73 / 84, subject_81_Vid_7 Already processed, skipping it.
# 74 / 84, subject_82_Vid_7 Already processed, skipping it.
# 75 / 84, subject_83_Vid_7 Already processed, skipping it.
# 76 / 84, subject_84_Vid_1 Already processed, skipping it.
# 77 / 84, subject_84_Vid_2 Already processed, skipping it.
# 78 / 84, subject_84_Vid_3 Already processed, skipping it.
# 79 / 84, subject_84_Vid_4 Already processed, skipping it.
# 80 / 84, subject_84_Vid_5 Already processed, skipping it.
# 81 / 84, subject_84_Vid_6 Already processed, skipping it.
# 82 / 84, subject_85_Vid_7 Already processed, skipping it.
# 83 / 84, subject_86_Vid_7 Already processed, skipping it.
# 84 / 84, subject_87_Vid_3 Already processed, skipping it.

# %%
len(glob.glob(train_frames_dir + "/*/*.jpg"))
# Out:
# 64152

# %%
len(glob.glob(train_frames_dir + "/*/*.txt"))
# Out:
# 53748

# %%
val_already_proccessed_file = "notebooks/val_already_proccessed_sub_folders"

# %%
with open(val_already_proccessed_file, "r") as f:
  val_already_proccessed_sub_folders = json.loads(f.read())

len(val_already_proccessed_sub_folders)
# Out:
# 21

# %%
# validation frames

face_not_found_frames = []

for i, sub_folder in enumerate(sorted(os.listdir(val_frames_dir))):
  if sub_folder in val_already_proccessed_sub_folders:
    print(f"{ i + 1} / {len(os.listdir(val_frames_dir))}, {sub_folder} Already processed, skipping it.")
    continue

  print(f"{ i + 1} / {len(os.listdir(val_frames_dir))}, {sub_folder}")
  for frame in tqdm(sorted(os.listdir(os.path.join(val_frames_dir, sub_folder)))):
    if frame.endswith(".txt"):
      continue

    frame_path = os.path.join(val_frames_dir, sub_folder, frame)
    bbox = get_face_bbox(frame_path)

    if not bbox:
      face_not_found_frames.append(frame_path)
      continue

    bbox_filepath = frame_path.replace(".jpg", ".txt")
    with open(bbox_filepath, "w") as fin:
      fin.write(" ".join(map(str, bbox)))

  update_list_of_items(filepath=val_already_proccessed_file, new_item=sub_folder)
# Out:
# 1 / 21, subject_1_Vid_1 Already processed, skipping it.
# 2 / 21, subject_1_Vid_2 Already processed, skipping it.
# 3 / 21, subject_1_Vid_3 Already processed, skipping it.
# 4 / 21, subject_1_Vid_4 Already processed, skipping it.
# 5 / 21, subject_1_Vid_5 Already processed, skipping it.
# 6 / 21, subject_2_Vid_6 Already processed, skipping it.
# 7 / 21, subject_3_Vid_1 Already processed, skipping it.
# 8 / 21, subject_3_Vid_2 Already processed, skipping it.
# 9 / 21, subject_3_Vid_3 Already processed, skipping it.
# 10 / 21, subject_3_Vid_4 Already processed, skipping it.
# 11 / 21, subject_3_Vid_5 Already processed, skipping it.
# 12 / 21, subject_3_Vid_7 Already processed, skipping it.
# 13 / 21, subject_4_Vid_6 Already processed, skipping it.
# 14 / 21, subject_5_Vid_6 Already processed, skipping it.
# 15 / 21, subject_6_Vid_6 Already processed, skipping it.
# 16 / 21, subject_7_Vid_1 Already processed, skipping it.
# 17 / 21, subject_7_Vid_2 Already processed, skipping it.
# 18 / 21, subject_7_Vid_3 Already processed, skipping it.
# 19 / 21, subject_7_Vid_4 Already processed, skipping it.
# 20 / 21, subject_7_Vid_5 Already processed, skipping it.
# 21 / 21, subject_8_Vid_6 Already processed, skipping it.

# %%
len(face_not_found_frames)
# Out:
# 0

# %%
len(glob.glob(val_frames_dir + "/*/*.jpg"))
# Out:
# 21971

# %%
len(glob.glob(val_frames_dir + "/*/*.txt"))
# Out:
# 18791
